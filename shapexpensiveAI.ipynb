# %%
# %run "AdvanceCode.ipynb"
# Out:
# ✅ Data Loaded: 55392 rows, 14 columns
# ✅ Realistic Billing Amount Created
# count     55392.00
# mean      49633.28
# std       17776.63
# min        6241.25
# 25%       36077.50
# 50%       48967.34
# 75%       60937.71
# max      113977.50
# Name: Billing_Amount, dtype: float64
# ✅ Model Trained
#    R² Score : 0.9871
#    MAE      : $1,617.71
# <div style='
#     background: linear-gradient(135deg, #1a73e8, #0d47a1);
#     padding: 25px 40px;
#     border-radius: 12px;
#     text-align: center;
#     margin-bottom: 25px;
#     width: 100%;
#     box-sizing: border-box;
# '>
#     <h1 style='color:white; margin:0; font-size:32px; letter-spacing:1px;'>
#         🏥 Healthcare Billing Prediction System
#     </h1>
#     <p style='color:#cce5ff; margin:8px 0 0 0; font-size:15px;'>
#         Enter patient details below to predict the estimated billing cost
#     </p>
# </div>
# ...

# %%
# Shap Expansible AI

import shap
import matplotlib.pyplot as plt

feature_names = [
    "Age",
    "Gender",
    "Medical Condition",
    "Admission Type",
    "Insurance Provider",
    "Length of Stay",
    "Medication",
    "Test Results",
]

explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_test)

# ── 1. Summary Plot — Global Feature Importance ───────
plt.figure()
shap.summary_plot(shap_values, X_test, feature_names=feature_names, show=True)

# ── 2. Bar Plot — Average Impact ──────────────────────
plt.figure()
shap.summary_plot(
    shap_values, X_test, feature_names=feature_names, plot_type="bar", show=True
)

# ── 3. Waterfall Plot — Single Patient Explanation ────

explanation = shap.Explanation(
    values=shap_values[0],
    base_values=explainer.expected_value,
    data=X_test.iloc[0].values,
    feature_names=feature_names,
)

plt.figure()
shap.plots.waterfall(explanation, show=True)
# Out:
# C:\Users\prasa\AppData\Local\Temp\ipykernel_16500\3935589837.py:17: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
# C:\Users\prasa\AppData\Local\Temp\ipykernel_16500\3935589837.py:26: FutureWarning: The NumPy global RNG was seeded by calling `np.random.seed`. In a future version this function will no longer use the global RNG. Pass `rng` explicitly to opt-in to the new behaviour and silence this warning.
#   shap.summary_plot(
